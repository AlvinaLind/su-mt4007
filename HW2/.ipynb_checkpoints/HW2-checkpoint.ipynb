# %% [markdown]
# ## Apartment prices
#
# 1. Calculate the price per square meter (ppsqm) for each apartment sold. That is, add a new variable to your table containing the data representing the ppsqm.
#
# 2. Rank the top 5 most expensive appartments w.r.t ppsqm. Present this in a table. Hint: Use a sort function.
#
# 3. What is the avereage ppsqm in Ekhagen?
#
# 4. Highlight an aspect of the data that you find interesting. Explain your choice.

# %%
import pandas as pd
data = pd.read_csv("/Users/alvinalindqvist/Desktop/Booli_sold.csv")
data.head(len(data))
# Out:
#      listPrice    rent  livingArea  rooms            published  \
# 0      3995000  4467.0        73.0    3.0  2018-10-15 13:33:18
# 1      1995000  1773.0        36.0    1.0  2018-10-05 14:29:28
# 2      5100000  3839.0        81.0    3.0  2018-09-11 13:44:43
# 3      5495000  4483.0       107.0    4.0  2018-08-25 02:56:56
# 4      1995000  1696.0        29.0    1.0  2018-06-15 17:16:19
# ..         ...     ...         ...    ...                  ...
# 153    1495000  1388.0        26.0    1.0  2012-10-20 07:36:37
# 154    2245000  2455.0        50.0    2.0  2012-10-19 15:32:58
# 155    1450000  1072.0        23.0    1.0  2012-09-14 05:10:08
# 156    2495000  2748.0        56.0    3.0  2012-09-21 12:19:37
# 157    2300000  2455.0        50.0    2.0  2012-09-16 02:33:35
#
#      constructionYear objectType  booliId    soldDate  soldPrice  ...  \
# 0              1935.0   Lägenhet  3263989  2018-11-08    3820000  ...
# ...

# %%
data["ppsqm"] = data["listPrice"]/data["livingArea"]
data[['listPrice', 'livingArea', 'ppsqm']].head()
# Out:
#    listPrice  livingArea         ppsqm
# 0    3995000        73.0  54726.027397
# 1    1995000        36.0  55416.666667
# 2    5100000        81.0  62962.962963
# 3    5495000       107.0  51355.140187
# 4    1995000        29.0  68793.103448

# %%
top_5_expensive = data.sort_values(by="ppsqm", ascending=False).head(5)
top_5_expensive[['listPrice', 'livingArea', 'ppsqm']]
# Out:
#     listPrice  livingArea         ppsqm
# 10    2295000        29.0  79137.931034
# 50    1890000        24.0  78750.000000
# 54    1795000        23.0  78043.478261
# 49    3495000        47.0  74361.702128
# 24    2500000        35.0  71428.571429

# %%
mean_ppsqm = data["ppsqm"].mean()
print("The average price per square meter is ", mean_ppsqm, "SEK")
# Out:
# The average price per square meter is  54127.43692133397 SEK

# %%
data["livingArea"].mean()
# Out:
# 64.97324840764333

# %% [markdown]
# One interesting aspect is that the average living area for apartments in Ekahagen is approximately 64.5 square meters, while the five most expensive apartments per square meter have significantly smaller living areas.

# %% [markdown]
# ## The Swedish Election of 2018
#
# 1. Calculate the total number of legitimate votes (Giltiga Röster) in Stockholm during the election. That is, sum upp the number of legitimate votes for all municipalities (kommun) in Stockholm.
#
# 2. In which municipality did the social democratic party (Social demokraterna, S) garner the hightest voting percentage?
#
# 3. Rank the (3) municipialities with highest participation (valdeltagande). Present this in the form of a table.

# %%
data2 = pd.read_csv("/Users/alvinalindqvist/Desktop/2018_R_per_kommun.csv", sep=";", decimal=',')
data2.head(len(data2))
# Out:
#      LÄNSKOD  KOMMUNKOD         LÄNSNAMN      KOMMUNNAMN      M      C     L  \
# 0          1         14   Stockholms län  Upplands Väsby  23.11   6.26  5.66
# 1          1         15   Stockholms län      Vallentuna  28.29  10.11  7.73
# 2          1         17   Stockholms län       Österåker  29.68   9.35  7.48
# 3          1         20   Stockholms län          Värmdö  27.49   9.76  6.40
# 4          1         23   Stockholms län        Järfälla  23.96   6.31  6.04
# ..       ...        ...              ...             ...    ...    ...   ...
# 285       25         80  Norrbottens län           Luleå  15.38   7.53  4.37
# 286       25         81  Norrbottens län           Piteå  11.82   7.49  2.52
# 287       25         82  Norrbottens län           Boden  14.32   6.23  3.61
# 288       25         83  Norrbottens län       Haparanda  12.79   9.61  1.86
# 289       25         84  Norrbottens län          Kiruna  10.71   5.38  2.51
#
# ...

# %%
stockholm_data = data2[data2["LÄNSNAMN"] == "Stockholms län"]

total_legitimate_votes_stockholm = stockholm_data["RÖSTER GILTIGA"].sum()

print("The total number of legitimate votes in Stockholms län is:",total_legitimate_votes_stockholm)
# Out:
# The sum of legitime votes in Stockholms län is: 1426237

# %%
highest_S_votes = data2["S"].max()
highest_S_municipality = data2.loc[data2["S"] == highest_S_votes, "KOMMUNNAMN"].iloc[0]
print("The municipality where the social democratic party garnered the hightest voting percentage is", highest_S_municipality)
# Out:
# The municipality where the social democratic party garnered the hightest voting percentage is Munkfors

# %%
top_3_participation = data2.sort_values("VALDELTAGANDE", ascending=False)
print("The three municipialities with highest participation is presented in the table below")
data_swedish_election_sort2.head(3)
# Out:
# The three municipialities with highest participation is presented in the table below
#      LÄNSKOD  KOMMUNKOD        LÄNSNAMN KOMMUNNAMN      M     C     L     KD  \
# 103       12         62       Skåne län      Lomma  33.16  9.33  9.97   6.38
# 59         6         43  Jönköpings län       Habo  19.73  8.77  4.22  15.13
# 98        12         33       Skåne län   Vellinge  39.56  7.24  7.26   7.45
#
#          S     V  ...  TRP  VL-S  ÖVR  OGEJ  BLANK    OG  RÖSTER GILTIGA  \
# 103  16.69  2.54  ...  NaN   NaN  NaN   NaN   0.51  0.04           16401
# 59   23.74  3.91  ...  NaN   NaN  NaN  0.06   0.88  0.06            7746
# 98   10.58  1.31  ...  0.0   NaN  NaN  0.02   0.40  0.04           25245
#
#      RÖSTANDE  RÖSTBERÄTTIGADE  VALDELTAGANDE
# 103     16492            17570          93.86
# 59       7825             8382          93.35
# 98      25360            27231          93.13
#
# [3 rows x 45 columns]

# %% [markdown]
# ## Predicting Strokes

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

strokes_df = pd.read_csv("/Users/alvinalindqvist/Desktop/stroke-data.csv")

stroke_proportions = strokes_df.groupby("work_type")["stroke"].mean() * 100

stroke_proportions.plot.bar()
plt.title("Proportion of Stroke Cases by Work Type")
plt.ylabel("Percentage of Stroke Cases")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# One conclusion we can draw is that individuals who are self-employed appear to have the highest percentage and potentially the highest risk of having a stroke.
